# %% [markdown]
# # 07 Full Analysis Pipeline
#
# 重心計算、毎秒可視化、前提検定、ANOVA、Tukey HSDまでを一連で実行するNotebook。

# %%
from pathlib import Path

import pandas as pd
import numpy as np

PROJECT_ROOT = Path.cwd().parent.parent if Path.cwd().name in ('重心', 'effective_area') else Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATA_RAW = PROJECT_ROOT / 'data' / 'raw'
DATA_PROCESSED = PROJECT_ROOT / 'data' / 'processed'
TABLES_DIR = PROJECT_ROOT / 'outputs' / 'tables'
FIGURES_DIR = PROJECT_ROOT / 'outputs' / 'figures'

TABLES_DIR.mkdir(parents=True, exist_ok=True)
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

ALPHA = 0.05

# %% [markdown]
# ## 実行順
#
# 1. データ読み込み
# 2. 重心計算
# 3. 毎秒重心可視化
# 4. Shapiro-Wilk検定
# 5. Levene検定
# 6. 一元配置分散分析
# 7. Tukey HSD
# 8. 表と図の保存
